# %%
notebooks = [
    "./gold_customer_info_joined",
    "./gold_product_info_joined",
    "./gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
