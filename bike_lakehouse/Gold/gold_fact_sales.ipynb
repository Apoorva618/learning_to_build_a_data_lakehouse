# %%
## creating the fact_sales table 
df = spark.table("workspace.silver.crm_sales_info_cleaned")
df.display()

# %%
## write to gold layer 
df.write.mode("overwrite").saveAsTable("workspace.gold.fact_sales_info")
