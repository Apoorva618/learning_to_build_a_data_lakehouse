-- %%
-- SHOW TABLES
-- DESCRIBE TABLE workspace.salesdb.dim_customers
-- DESCRIBE TABLE workspace.salesdb.dim_products

-- List all unique customer countries
-- SELECT DISTINCT country FROM workspace.salesdb.dim_customers

-- List all unique product categories and subcategories
--SELECT DISTINCT category AS distinctCategories
--FROM workspace.salesdb.dim_products

--SELECT DISTINCT subcategory AS distinctSubcategories
--FROM workspace.salesdb.dim_products

-- SELECT SUM(sales_amount) as totalsales, 
--        COUNT(customer_key) as totalcustomers,
--        COUNT(DISTINCT product_key) as totalproducts,
--        COUNT(order_number) AS totalorders
-- FROM workspace.salesdb.fact_sales

-- Sales by Product 
-- SELECT product_key,SUM(sales_amount) as totalsales
-- FROM workspace.salesdb.fact_sales
-- GROUP BY product_key
-- ORDER BY totalsales

-- Sales by Category 
-- SELECT dim_products.category,SUM(fact_sales.sales_amount) as totalsales
-- FROM workspace.salesdb.fact_sales
-- JOIN workspace.salesdb.dim_products ON fact_sales.product_key = dim_products.product_key
-- GROUP BY dim_products.category
-- ORDER BY totalsales

-- Orders over time 
-- SELECT order_date,SUM(sales_amount) as totalsales
-- FROM workspace.salesdb.fact_sales
-- GROUP BY order_date
-- ORDER BY order_date DESC
